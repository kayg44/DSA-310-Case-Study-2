# %%
# !pip install pdfplumber
# Out:
# 368.02s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 23.7 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 29.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pdfplumber]3 [pdfminer.six]
# ...

# %%
from src.extract import extract_and_clean
from src.chunk import chunk_text
import pandas as pd

# Step 1: extract & clean
text = extract_and_clean("../Data/Mastercard/annual_report_excerpt.pdf")

# Step 2: chunk
chunks = chunk_text(text, chunk_size=700, overlap=50)

print(len(text))  # length of extracted text
print(len(chunks))  # number of chunks

# Step 3: save
df = pd.DataFrame(chunks)
df.to_csv("../chunks.csv", index=False)
df.head()
