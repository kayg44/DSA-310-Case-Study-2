# %%
import sys, os
import pandas as pd

# make src importable
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.append(project_root)

from src.retrieval import TfidfRetriever
from src.qa import call_llm_ollama

# Load retriever
retriever = TfidfRetriever("../chunks.csv")

# %%
pip install ollama
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
question = "What does Mastercard do as a business, and what are its main strategic priorities?"
top_chunks = retriever.retrieve(question, k=5)

answer = call_llm_ollama(question, top_chunks, model="llama3")
print(answer)
# Out:
# Mastercard is a technology company in the global payments industry that connects consumers, financial institutions, merchants, governments, digital partners, businesses, and other organizations worldwide by enabling electronic payments and making those payment transactions secure, simple, smart, and accessible. [chunk_2]
#
# As a business, Mastercard helps people make payments easier and more efficient by providing a wide range of payment solutions and services using its family of well-known and trusted brands, including Mastercard, Maestro, and Cirrus. [chunk_2] The company operates a payments network that provides choice and flexibility for consumers, merchants, and customers, and it has additional payments capabilities that include automated clearing house (ACH) transactions. [chunk_2]
#
# ...

# %%
pip install streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !streamlit run app/streamlit_app.py
# Out:
# Usage: streamlit run [OPTIONS] TARGET [ARGS]...
# Try 'streamlit run --help' for help.
#
# Error: Invalid value: File does not exist: app/streamlit_app.py
